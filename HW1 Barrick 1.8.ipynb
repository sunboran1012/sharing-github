# %%
# !conda install -c anaconda seaborn -y
#problem 1.8 (a)
import numpy as np
import random
import seaborn as sns 

n=10
p=0.5
mu=4.97
sigma=1.53

x=np.random.normal(4.97,1.53,size=1000)
sns.distplot(x)
# Out:
# ...
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.8.2
#   latest version: 4.8.4
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# ## Package Plan ##
#
#   environment location: /srv/conda/envs/notebook
#
#   added / updated specs:
#     - seaborn
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2020.7.22  |                0         132 KB  anaconda
#     certifi-2020.6.20          |           py36_0         160 KB  anaconda
#     openssl-1.1.1g             |       h7b6447c_0         3.8 MB  anaconda
#     seaborn-0.10.1             |             py_0         160 KB  anaconda
#     ------------------------------------------------------------
#                                            Total:         4.2 MB
#
# The following NEW packages will be INSTALLED:
#
# ...

# %%
#problem 1.8 (a)
import numpy as np
import random
import seaborn as sns 

n=1000
p=0.5
mu=500.02
sigma=15.66

x=np.random.normal(500.02,15.66,size=1000)
sns.distplot(x)

# %%
#probelm 1.8(b)
import numpy as np
from scipy.stats import binom
import matplotlib.pyplot as plt
import seaborn as sns

n=10
p=0.5
trials=100
heads=np.random.binomial(10,0.5,100)
sns.distplot(heads)

# %%
#probelm 1.8(b)
import numpy as np
from scipy.stats import binom
import matplotlib.pyplot as plt
import seaborn as sns

n=1000
p=0.5
trials=10000
heads=np.random.binomial(1000,0.5,10000)
sns.distplot(heads)

# %%
#probelm 1.8(c)
import numpy as np
from scipy.stats import norm
import matplotlib.pyplot as plt


n=10
p=0.5
trials=100
heads=norm.rvs(4.97,1.53,size=1000)
heads_fit=norm.fit(heads)
x=np.linspace(0,10,1)

plt.hist(heads)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
#probelm 1.8(c)
import numpy as np
from scipy.stats import norm
import matplotlib.pyplot as plt


n=1000
p=0.5
trials=10000
heads=norm.rvs(500.02,15.66,size=10000)
heads_fit=norm.fit(heads)
x=np.linspace(0,2000,100)

plt.hist(heads)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
